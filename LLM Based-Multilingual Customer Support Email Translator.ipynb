# %% [markdown]
# ## Import Necessary Librarey

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain.prompts import ChatPromptTemplate
from langchain.chains import SequentialChain, LLMChain

# %% [markdown]
# ## Reading in our example Email Text File

# %%
with open("spanish_customer_email.txt","r",errors="replace") as file:
    email=file.read()

# %%
print(email)
# Out:
# ��Asunto: Reporte de Problemas T�cnicos - Funcionalidad del Panel SAAS
#
# Estimado Equipo de Soporte al Cliente,
#
# Espero que este mensaje les encuentre bien. Les escribo para informarles sobre un problema t�cnico que he encontrado mientras utilizo su producto de panel SAAS. Como cliente leal, aprecio el valor que su producto aporta a mi negocio, pero actualmente me enfrento a un desaf�o que requiere su experiencia.
#
# Me gustar�a describir detalladamente el problema que estoy experimentando:
#
# 1. Problema Gr�fico: Al iniciar sesi�n en el panel SAAS, he notado que los gr�ficos y las tablas en la p�gina principal del panel no se renderizan correctamente. Los puntos de datos aparecen distorsionados y algunos elementos se superponen, lo que dificulta la interpretaci�n precisa de la informaci�n.
#
# 2. Fallo en la Funci�n de Exportaci�n: Adem�s, no he podido exportar informes y datos desde el panel. Cada vez que intento exportar un informe en formato CSV o PDF, recibo un mensaje de error que indica que la exportaci�n ha fallado. Esta funcionalidad es crucial para compartir informaci�n con mi equipo y partes interesadas externas, por lo que es imperativo que se resuelva r�pidamente.
#
# 3. Lentitud en la Carga: Durante la �ltima semana, he notado una disminuci�n significativa en la velocidad de carga del panel SAAS. Las p�ginas tardan un tiempo inusualmente largo en cargarse, lo que afecta mi productividad y genera frustraci�n. Tengo una conexi�n a internet confiable, por lo que creo que el problema radica en el panel mismo.
#
# Ya he realizado los siguientes pasos para solucionar el problema:
#
# 1. Limpieza de Cache: Limpi� la memoria cach� y las cookies de mi navegador para asegurarme de que los datos desactualizados no est�n causando conflictos. Sin embargo, los problemas persisten incluso despu�s de realizar esta acci�n.
#
# 2. Varios Navegadores: Prob� el panel SAAS en diferentes navegadores web (Chrome, Firefox y Safari) para determinar si el problema era espec�fico del navegador. Desafortunadamente, los problemas gr�ficos, los fallos en la exportaci�n y la lentitud en la carga persistieron en todos los navegadores.
#
# Les solicito amablemente su ayuda para resolver estos problemas, ya que est�n obstaculizando mi capacidad de aprovechar todo el potencial de su panel SAAS. Aqu� est�n las acciones espec�ficas que agradecer�a:
#
# 1. Soluci�n para Problemas Gr�ficos: Por favor, investiguen y corrijan los problemas gr�ficos presentes en la p�gina principal del panel para garantizar una visualizaci�n precisa de los datos.
#
# 2. Soluci�n para la Funci�n de Exportaci�n: Identifiquen y solucionen el problema con la exportaci�n de informes en formatos CSV y PDF, permiti�ndome compartir datos con mi equipo y partes interesadas de manera fluida.
#
# 3. Optimizaci�n del Rendimiento: Por favor, aborden la lentitud en la carga del panel SAAS para mejorar la experiencia general del usuario y aumentar la productividad.
#
# Entiendo que los problemas t�cnicos pueden surgir de vez en cuando y aprecio su pronta atenci�n a este asunto. Si requieren informaci�n adicional o ayuda de mi parte, no duden en contactarme. Espero su pronta respuesta y una pronta resoluci�n a estos desaf�os.
#
# Gracias por su comprensi�n y apoyo.
#
# Atentamente,
#
# Mar�a Rodr�guez
# ID de Cliente: 123456789
# Informaci�n de la Cuenta: Empresa Ejemplo S.A.

# %% [markdown]
# ## Function to fill out

# %%
def transulate_and_summaryize(email):
    
    llm=ChatGoogleGenerativeAI(model="gemini-1.5-flash-latest",
                               google_api_key="AIzaSyCcWB1RWS0bGlrbltdFNhFqONTyUpYZnjg",
                               temperature=0,)
   # Detect Language
    template1 = "Return the language this email is written in:\n{email}.\nONLY return the language it was written in."
    prompt1 = ChatPromptTemplate.from_template(template1)
    chain_1 = LLMChain(llm=llm,
                     prompt=prompt1,
                     output_key="language")
    
    # Translate from detected language to English
    template2 = "Translate this email from {language} to English. Here is the email:\n"+email
    prompt2 = ChatPromptTemplate.from_template(template2)
    chain_2 = LLMChain(llm=llm,
                     prompt=prompt2,
                     output_key="translated_email")
    
    # Return English Summary AND the Translated Email
    template3 = "Create a short summary of this email:\n{translated_email}"
    prompt3 = ChatPromptTemplate.from_template(template3)
    chain_3 = LLMChain(llm=llm,
                     prompt=prompt3,
                     output_key="summary")
    
    seq_chain = SequentialChain(chains=[chain_1,chain_2,chain_3],
                            input_variables=['email'],
                            output_variables=['language','translated_email','summary'],
                            verbose=True)
    return seq_chain(email)

# %% [markdown]
# ## Result

# %%
result=transulate_and_summaryize(email)
# Out:
# /home/balaji/.local/lib/python3.10/site-packages/langchain_core/_api/deprecation.py:139: LangChainDeprecationWarning: The class `LLMChain` was deprecated in LangChain 0.1.17 and will be removed in 1.0. Use RunnableSequence, e.g., `prompt | llm` instead.
#   warn_deprecated(
# /home/balaji/.local/lib/python3.10/site-packages/langchain_core/_api/deprecation.py:139: LangChainDeprecationWarning: The method `Chain.__call__` was deprecated in langchain 0.1.0 and will be removed in 0.3.0. Use invoke instead.
#   warn_deprecated(
# > Entering new SequentialChain chain...
#
# > Finished chain.

# %%
result.keys()
# Out:
# dict_keys(['email', 'language', 'translated_email', 'summary'])

# %%
print(result['email'])
# Out:
# ��Asunto: Reporte de Problemas T�cnicos - Funcionalidad del Panel SAAS
#
# Estimado Equipo de Soporte al Cliente,
#
# Espero que este mensaje les encuentre bien. Les escribo para informarles sobre un problema t�cnico que he encontrado mientras utilizo su producto de panel SAAS. Como cliente leal, aprecio el valor que su producto aporta a mi negocio, pero actualmente me enfrento a un desaf�o que requiere su experiencia.
#
# Me gustar�a describir detalladamente el problema que estoy experimentando:
#
# 1. Problema Gr�fico: Al iniciar sesi�n en el panel SAAS, he notado que los gr�ficos y las tablas en la p�gina principal del panel no se renderizan correctamente. Los puntos de datos aparecen distorsionados y algunos elementos se superponen, lo que dificulta la interpretaci�n precisa de la informaci�n.
#
# 2. Fallo en la Funci�n de Exportaci�n: Adem�s, no he podido exportar informes y datos desde el panel. Cada vez que intento exportar un informe en formato CSV o PDF, recibo un mensaje de error que indica que la exportaci�n ha fallado. Esta funcionalidad es crucial para compartir informaci�n con mi equipo y partes interesadas externas, por lo que es imperativo que se resuelva r�pidamente.
#
# 3. Lentitud en la Carga: Durante la �ltima semana, he notado una disminuci�n significativa en la velocidad de carga del panel SAAS. Las p�ginas tardan un tiempo inusualmente largo en cargarse, lo que afecta mi productividad y genera frustraci�n. Tengo una conexi�n a internet confiable, por lo que creo que el problema radica en el panel mismo.
#
# Ya he realizado los siguientes pasos para solucionar el problema:
#
# 1. Limpieza de Cache: Limpi� la memoria cach� y las cookies de mi navegador para asegurarme de que los datos desactualizados no est�n causando conflictos. Sin embargo, los problemas persisten incluso despu�s de realizar esta acci�n.
#
# 2. Varios Navegadores: Prob� el panel SAAS en diferentes navegadores web (Chrome, Firefox y Safari) para determinar si el problema era espec�fico del navegador. Desafortunadamente, los problemas gr�ficos, los fallos en la exportaci�n y la lentitud en la carga persistieron en todos los navegadores.
#
# Les solicito amablemente su ayuda para resolver estos problemas, ya que est�n obstaculizando mi capacidad de aprovechar todo el potencial de su panel SAAS. Aqu� est�n las acciones espec�ficas que agradecer�a:
#
# 1. Soluci�n para Problemas Gr�ficos: Por favor, investiguen y corrijan los problemas gr�ficos presentes en la p�gina principal del panel para garantizar una visualizaci�n precisa de los datos.
#
# 2. Soluci�n para la Funci�n de Exportaci�n: Identifiquen y solucionen el problema con la exportaci�n de informes en formatos CSV y PDF, permiti�ndome compartir datos con mi equipo y partes interesadas de manera fluida.
#
# 3. Optimizaci�n del Rendimiento: Por favor, aborden la lentitud en la carga del panel SAAS para mejorar la experiencia general del usuario y aumentar la productividad.
#
# Entiendo que los problemas t�cnicos pueden surgir de vez en cuando y aprecio su pronta atenci�n a este asunto. Si requieren informaci�n adicional o ayuda de mi parte, no duden en contactarme. Espero su pronta respuesta y una pronta resoluci�n a estos desaf�os.
#
# Gracias por su comprensi�n y apoyo.
#
# Atentamente,
#
# Mar�a Rodr�guez
# ID de Cliente: 123456789
# Informaci�n de la Cuenta: Empresa Ejemplo S.A.

# %%
print(result['language'])
# Out:
# Spanish

# %%
print(result['translated_email'])
# Out:
# ## Subject: Technical Issue Report - SaaS Panel Functionality
#
# Dear Client Support Team,
#
# I hope this message finds you well. I am writing to inform you about a technical issue I have encountered while using your SaaS panel product. As a loyal customer, I appreciate the value your product brings to my business, but I am currently facing a challenge that requires your expertise.
#
# I would like to describe in detail the problem I am experiencing:
#
# 1. **Graphical Issue:** Upon logging into the SaaS panel, I have noticed that the graphs and tables on the main page of the panel are not rendering correctly. Data points appear distorted, and some elements overlap, making it difficult to accurately interpret the information.
#
# 2. **Export Function Failure:** Additionally, I have been unable to export reports and data from the panel. Every time I attempt to export a report in CSV or PDF format, I receive an error message indicating that the export has failed. This functionality is crucial for sharing information with my team and external stakeholders, so it is imperative that it is resolved promptly.
#
# 3. **Slow Loading:** Over the past week, I have noticed a significant decrease in the loading speed of the SaaS panel. Pages take an unusually long time to load, affecting my productivity and causing frustration. I have a reliable internet connection, so I believe the problem lies with the panel itself.
#
# I have already taken the following steps to try and resolve the issue:
#
# 1. **Cache Clearing:** I cleared the cache and cookies of my browser to ensure that outdated data is not causing conflicts. However, the problems persist even after performing this action.
#
# 2. **Multiple Browsers:** I tried the SaaS panel in different web browsers (Chrome, Firefox, and Safari) to determine if the problem was browser-specific. Unfortunately, the graphical issues, export failures, and slow loading persisted in all browsers.
#
# I kindly request your assistance in resolving these issues, as they are hindering my ability to fully utilize the potential of your SaaS panel. Here are the specific actions I would appreciate:
#
# 1. **Solution for Graphical Issues:** Please investigate and correct the graphical problems present on the main page of the panel to ensure accurate visualization of the data.
#
# 2. **Solution for Export Function:** Identify and resolve the problem with the export of reports in CSV and PDF formats, allowing me to share data with my team and stakeholders smoothly.
#
# 3. **Performance Optimization:** Please address the slow loading of the SaaS panel to improve the overall user experience and increase productivity.
#
# I understand that technical issues can arise from time to time, and I appreciate your prompt attention to this matter. If you require any additional information or assistance from my end, please do not hesitate to contact me. I look forward to your prompt response and a swift resolution to these challenges.
#
# Thank you for your understanding and support.
#
# Sincerely,
#
# Maria Rodriguez
# Client ID: 123456789
# Account Information: Empresa Ejemplo S.A.

# %%
print(result['summary'])
# Out:
# This email reports technical issues with the SaaS panel, including distorted graphs, failed exports, and slow loading times. The client has tried troubleshooting steps but the problems persist. They request solutions for each issue to ensure accurate data visualization, successful report exports, and improved panel performance.
